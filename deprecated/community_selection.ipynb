# %% [markdown]
# # Community functions
# This tutorial provides a minimal example for conducting community-level selection.

# %%
# Community simulator package
from IPython.display import Image
from community_simulator import *
from community_simulator.usertools import *
from community_simulator.visualization import *
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.backends import backend_pdf as bpdf
import numpy as np
import scipy as sp
colors = sns.color_palette()
# %matplotlib inline

# Community selection package
from community_selection import *
from community_selection.A_experiment_functions import *
from community_selection.B_community_phenotypes import *
from community_selection.C_selection_algorithms import *
from community_selection.D_migration_algorithms import *

# %%
# Make dynanmics by default we will use the microbial consumer resource model
def dNdt(N,R,params):
    return MakeConsumerDynamics(assumptions)(N,R,params)
def dRdt(N,R,params):
    return MakeResourceDynamics(assumptions)(N,R,params)
dynamics = [dNdt,dRdt]

# Global parameters
## Default parameters from community-simulator
## !!!Don't touch this dictionary!!!
assumptions = a_default.copy() # Start with default parameters
a_default = {'sampling':'Binary', #{'Gaussian','Binary','Gamma'} specifies choice of sampling algorithm
            'SA': 60*np.ones(3), #Number of species in each specialist family (here, 3 families of 60 species)
            'MA': 30*np.ones(3), #Number of resources in each class 
            'Sgen': 30, #Number of generalist species (unbiased sampling over alll resource classes)
            'muc': 10, #Mean sum of consumption rates (used in all models)
            'sigc': 3, #Standard deviation of sum of consumption rates for Gaussian and Gamma models
            'q': 0.0, #Preference strength of specialist families (0 for generalist and 1 for specialist)
            'c0':0.0, #Sum of background consumption rates in binary model
            'c1':1., #Specific consumption rate in binary model
            'l':0.8, #Leakage fraction
            'fs':0.45, #Fraction of secretion flux with same resource type
            'fw':0.45, #Fraction of secretion flux to 'waste' resource
            'sparsity':0.2, #Effective sparsity of metabolic matrix (between 0 and 1)
            'n_wells':10, #Number of independent wells
            'S':100, #Number of species per well (randomly sampled from the pool of size Stot = sum(SA) + Sgen)
            'food':0, #index of food source (when a single resource is supplied externally)
            'R0_food':1000, #unperturbed fixed point for supplied food
            'regulation':'independent', #metabolic regulation (see dRdt)
            'response':'type I', #functional response (see dRdt)
            'supply':'off' #resource supply (see dRdt)
            }

## Update parameters for community-selection
assumptions.update({
    'SA': 60*np.ones(3), #Number of species in each specialist family (here, 3 families of 60 species)
    'MA': 30*np.ones(3), #Number of resources in each class 
    'Sgen': 30, #Number of generalist species (unbiased sampling over alll resource classes)
    "n_wells": 24,
    "c1": 1, #Rescale uptake rate part 1. This is needed to avoid numerical errors that slow down the simulations
    "muc": 10, # Rescale uptake part 2
    "m": 0, # Mortality
    "scale": 10**6,  #scale is a conversion factor specifying the number of individual microbial cells present when N = 1.
    "sigma" : 1, # Standard deviation for drawing specifc speices/interaction function
    "alpha": 1, # Scaling factor between species- and interaction-specific function variances
    "l": 0, # Set leakage function to 0 to switch off cross-feeding
    "response": "type III",
    "sigma_max": 100,  # The maximal resource  
    'R0_food': 1000, # Total amount of supplied food 
    'rich_food': [0, 10, 20, 40, 80], # The indices of foods in the rich medium 
#    'rich_food': 0,
    # The parameters below will be passed to params_simulation
    "n_propagation": 8, # Length of propagation, or hours within a growth cycle
    "n_transfer": 40, # Number of total transfer, or number of passage
    "n_transfer_selection": 20, # Number of transfer implementing seleciton regimes 
    "dilution": 1/125, # Dilution factor at every transfer
    "n_inoc": 128,  #Number of cells sampled from the regional species at start
    "selected_function": "f1_additive"
})

# Prepare experiment setup in this universe
params, params_simulation = prepare_experiment(assumptions, seed = 1)

# %%
data_directory = "data/typeIII-24wells-rich_medium/"
list_phenotypes = ["f1_additive", "f2_interaction", "f3_additive_binary", "f4_interaction_binary", "f5_invader_growth", "f6_resident_growth"]
list_algorithms = ["simple_screening", "swenson2000", "direct_selection", "panke_buisse2015", "pair_top_communities", "multiple_pair_top"]


for j in range(len(list_phenotypes)):
    # Parameters for simulation
    params_simulation.update({"selected_function": list_phenotypes[j]}) # selected function

    # Make the list of algorithms
    algorithms = make_algorithms(params_simulation)
    
    # Simulation
    for i in range(len(list_algorithms)):
        simulate_community(
            assumptions = assumptions,
            params = params,
            dynamics = dynamics,
            params_simulation = params_simulation, 
            params_algorithm = algorithms[algorithms["algorithm_name"] == list_algorithms[i]], 
            write_composition = True,
            file_name = data_directory + list_algorithms[i],
            assembly_type = str(list_algorithms[i]),
        )
# Out:
# Algorithm: simple_screening
#
#
#  transfer community_phenotype selection_algorithm migration_algorithm
#         1         f1_additive        no_selection        no_migration
#         2         f1_additive        no_selection        no_migration
#         3         f1_additive        no_selection        no_migration
#         4         f1_additive        no_selection        no_migration
#         5         f1_additive        no_selection        no_migration
#         6         f1_additive        no_selection        no_migration
#         7         f1_additive        no_selection        no_migration
#         8         f1_additive        no_selection        no_migration
#         9         f1_additive        no_selection        no_migration
#        10         f1_additive        no_selection        no_migration
#        11         f1_additive        no_selection        no_migration
#        12         f1_additive        no_selection        no_migration
#        13         f1_additive        no_selection        no_migration
#        14         f1_additive        no_selection        no_migration
#        15         f1_additive        no_selection        no_migration
#        16         f1_additive        no_selection        no_migration
#        17         f1_additive        no_selection        no_migration
#        18         f1_additive        no_selection        no_migration
#        19         f1_additive        no_selection        no_migration
#        20         f1_additive        no_selection        no_migration
#        21         f1_additive        no_selection        no_migration
#        22         f1_additive        no_selection        no_migration
#        23         f1_additive        no_selection        no_migration
#        24         f1_additive        no_selection        no_migration
#        25         f1_additive        no_selection        no_migration
#        26         f1_additive        no_selection        no_migration
#        27         f1_additive        no_selection        no_migration
#        28         f1_additive        no_selection        no_migration
#        29         f1_additive        no_selection        no_migration
#        30         f1_additive        no_selection        no_migration
#        31         f1_additive        no_selection        no_migration
#        32         f1_additive        no_selection        no_migration
#        33         f1_additive        no_selection        no_migration
#        34         f1_additive        no_selection        no_migration
#        35         f1_additive        no_selection        no_migration
#        36         f1_additive        no_selection        no_migration
#        37         f1_additive        no_selection        no_migration
#        38         f1_additive        no_selection        no_migration
#        39         f1_additive        no_selection        no_migration
#        40         f1_additive        no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm simple_screening finished
#
# Algorithm: swenson2000
#
#
#  transfer community_phenotype  selection_algorithm migration_algorithm
#         1         f1_additive  select_top25percent        no_migration
#         2         f1_additive  select_top25percent        no_migration
#         3         f1_additive  select_top25percent        no_migration
#         4         f1_additive  select_top25percent        no_migration
#         5         f1_additive  select_top25percent        no_migration
#         6         f1_additive  select_top25percent        no_migration
#         7         f1_additive  select_top25percent        no_migration
#         8         f1_additive  select_top25percent        no_migration
#         9         f1_additive  select_top25percent        no_migration
#        10         f1_additive  select_top25percent        no_migration
#        11         f1_additive  select_top25percent        no_migration
#        12         f1_additive  select_top25percent        no_migration
#        13         f1_additive  select_top25percent        no_migration
#        14         f1_additive  select_top25percent        no_migration
#        15         f1_additive  select_top25percent        no_migration
#        16         f1_additive  select_top25percent        no_migration
#        17         f1_additive  select_top25percent        no_migration
#        18         f1_additive  select_top25percent        no_migration
#        19         f1_additive  select_top25percent        no_migration
#        20         f1_additive  select_top25percent        no_migration
#        21         f1_additive         no_selection        no_migration
#        22         f1_additive         no_selection        no_migration
#        23         f1_additive         no_selection        no_migration
#        24         f1_additive         no_selection        no_migration
#        25         f1_additive         no_selection        no_migration
#        26         f1_additive         no_selection        no_migration
#        27         f1_additive         no_selection        no_migration
#        28         f1_additive         no_selection        no_migration
#        29         f1_additive         no_selection        no_migration
#        30         f1_additive         no_selection        no_migration
#        31         f1_additive         no_selection        no_migration
#        32         f1_additive         no_selection        no_migration
#        33         f1_additive         no_selection        no_migration
#        34         f1_additive         no_selection        no_migration
#        35         f1_additive         no_selection        no_migration
#        36         f1_additive         no_selection        no_migration
#        37         f1_additive         no_selection        no_migration
#        38         f1_additive         no_selection        no_migration
#        39         f1_additive         no_selection        no_migration
#        40         f1_additive         no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm swenson2000 finished
#
# Algorithm: direct_selection
#
#
#  transfer community_phenotype      selection_algorithm       migration_algorithm
#         1         f1_additive             no_selection              no_migration
#         2         f1_additive             no_selection              no_migration
#         3         f1_additive             no_selection              no_migration
#         4         f1_additive             no_selection              no_migration
#         5         f1_additive             no_selection              no_migration
#         6         f1_additive             no_selection              no_migration
#         7         f1_additive             no_selection              no_migration
#         8         f1_additive             no_selection              no_migration
#         9         f1_additive             no_selection              no_migration
#        10         f1_additive             no_selection              no_migration
#        11         f1_additive             no_selection              no_migration
#        12         f1_additive             no_selection              no_migration
#        13         f1_additive             no_selection              no_migration
#        14         f1_additive             no_selection              no_migration
#        15         f1_additive             no_selection              no_migration
#        16         f1_additive             no_selection              no_migration
#        17         f1_additive             no_selection              no_migration
#        18         f1_additive             no_selection              no_migration
#        19         f1_additive             no_selection              no_migration
#        20         f1_additive  direct_selection_select  direct_selection_migrate
#        21         f1_additive             no_selection              no_migration
#        22         f1_additive             no_selection              no_migration
#        23         f1_additive             no_selection              no_migration
#        24         f1_additive             no_selection              no_migration
#        25         f1_additive             no_selection              no_migration
#        26         f1_additive             no_selection              no_migration
#        27         f1_additive             no_selection              no_migration
#        28         f1_additive             no_selection              no_migration
#        29         f1_additive             no_selection              no_migration
#        30         f1_additive             no_selection              no_migration
#        31         f1_additive             no_selection              no_migration
#        32         f1_additive             no_selection              no_migration
#        33         f1_additive             no_selection              no_migration
#        34         f1_additive             no_selection              no_migration
#        35         f1_additive             no_selection              no_migration
#        36         f1_additive             no_selection              no_migration
#        37         f1_additive             no_selection              no_migration
#        38         f1_additive             no_selection              no_migration
#        39         f1_additive             no_selection              no_migration
#        40         f1_additive             no_selection              no_migration
#
# Generating initial plate
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm direct_selection finished
#
# Algorithm: panke_buisse2015
#
#
#  transfer community_phenotype selection_algorithm migration_algorithm
#         1         f1_additive   pool_top25percent        no_migration
#         2         f1_additive   pool_top25percent        no_migration
#         3         f1_additive   pool_top25percent        no_migration
#         4         f1_additive   pool_top25percent        no_migration
#         5         f1_additive   pool_top25percent        no_migration
#         6         f1_additive   pool_top25percent        no_migration
#         7         f1_additive   pool_top25percent        no_migration
#         8         f1_additive   pool_top25percent        no_migration
#         9         f1_additive   pool_top25percent        no_migration
#        10         f1_additive   pool_top25percent        no_migration
#        11         f1_additive   pool_top25percent        no_migration
#        12         f1_additive   pool_top25percent        no_migration
#        13         f1_additive   pool_top25percent        no_migration
#        14         f1_additive   pool_top25percent        no_migration
#        15         f1_additive   pool_top25percent        no_migration
#        16         f1_additive   pool_top25percent        no_migration
#        17         f1_additive   pool_top25percent        no_migration
#        18         f1_additive   pool_top25percent        no_migration
#        19         f1_additive   pool_top25percent        no_migration
#        20         f1_additive   pool_top25percent        no_migration
#        21         f1_additive        no_selection        no_migration
#        22         f1_additive        no_selection        no_migration
#        23         f1_additive        no_selection        no_migration
#        24         f1_additive        no_selection        no_migration
#        25         f1_additive        no_selection        no_migration
#        26         f1_additive        no_selection        no_migration
#        27         f1_additive        no_selection        no_migration
#        28         f1_additive        no_selection        no_migration
#        29         f1_additive        no_selection        no_migration
#        30         f1_additive        no_selection        no_migration
#        31         f1_additive        no_selection        no_migration
#        32         f1_additive        no_selection        no_migration
#        33         f1_additive        no_selection        no_migration
#        34         f1_additive        no_selection        no_migration
#        35         f1_additive        no_selection        no_migration
#        36         f1_additive        no_selection        no_migration
#        37         f1_additive        no_selection        no_migration
#        38         f1_additive        no_selection        no_migration
#        39         f1_additive        no_selection        no_migration
#        40         f1_additive        no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm panke_buisse2015 finished
#
# Algorithm: pair_top_communities
#
#
#  transfer community_phenotype selection_algorithm migration_algorithm
#         1         f1_additive        no_selection        no_migration
#         2         f1_additive        no_selection        no_migration
#         3         f1_additive        no_selection        no_migration
#         4         f1_additive        no_selection        no_migration
#         5         f1_additive        no_selection        no_migration
#         6         f1_additive        no_selection        no_migration
#         7         f1_additive        no_selection        no_migration
#         8         f1_additive        no_selection        no_migration
#         9         f1_additive        no_selection        no_migration
#        10         f1_additive        no_selection        no_migration
#        11         f1_additive        no_selection        no_migration
#        12         f1_additive        no_selection        no_migration
#        13         f1_additive        no_selection        no_migration
#        14         f1_additive        no_selection        no_migration
#        15         f1_additive        no_selection        no_migration
#        16         f1_additive        no_selection        no_migration
#        17         f1_additive        no_selection        no_migration
#        18         f1_additive        no_selection        no_migration
#        19         f1_additive        no_selection        no_migration
#        20         f1_additive            pair_top        no_migration
#        21         f1_additive        no_selection        no_migration
#        22         f1_additive        no_selection        no_migration
#        23         f1_additive        no_selection        no_migration
#        24         f1_additive        no_selection        no_migration
#        25         f1_additive        no_selection        no_migration
#        26         f1_additive        no_selection        no_migration
#        27         f1_additive        no_selection        no_migration
#        28         f1_additive        no_selection        no_migration
#        29         f1_additive        no_selection        no_migration
#        30         f1_additive        no_selection        no_migration
#        31         f1_additive        no_selection        no_migration
#        32         f1_additive        no_selection        no_migration
#        33         f1_additive        no_selection        no_migration
#        34         f1_additive        no_selection        no_migration
#        35         f1_additive        no_selection        no_migration
#        36         f1_additive        no_selection        no_migration
#        37         f1_additive        no_selection        no_migration
#        38         f1_additive        no_selection        no_migration
#        39         f1_additive        no_selection        no_migration
#        40         f1_additive        no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm pair_top_communities finished
#
# Algorithm: multiple_pair_top
#
#
#  transfer community_phenotype selection_algorithm migration_algorithm
#         1         f1_additive            pair_top        no_migration
#         2         f1_additive            pair_top        no_migration
#         3         f1_additive            pair_top        no_migration
#         4         f1_additive            pair_top        no_migration
#         5         f1_additive            pair_top        no_migration
#         6         f1_additive            pair_top        no_migration
#         7         f1_additive            pair_top        no_migration
#         8         f1_additive            pair_top        no_migration
#         9         f1_additive            pair_top        no_migration
#        10         f1_additive            pair_top        no_migration
#        11         f1_additive            pair_top        no_migration
#        12         f1_additive            pair_top        no_migration
#        13         f1_additive            pair_top        no_migration
#        14         f1_additive            pair_top        no_migration
#        15         f1_additive            pair_top        no_migration
#        16         f1_additive            pair_top        no_migration
#        17         f1_additive            pair_top        no_migration
#        18         f1_additive            pair_top        no_migration
#        19         f1_additive            pair_top        no_migration
#        20         f1_additive            pair_top        no_migration
#        21         f1_additive        no_selection        no_migration
#        22         f1_additive        no_selection        no_migration
#        23         f1_additive        no_selection        no_migration
#        24         f1_additive        no_selection        no_migration
#        25         f1_additive        no_selection        no_migration
#        26         f1_additive        no_selection        no_migration
#        27         f1_additive        no_selection        no_migration
#        28         f1_additive        no_selection        no_migration
#        29         f1_additive        no_selection        no_migration
#        30         f1_additive        no_selection        no_migration
#        31         f1_additive        no_selection        no_migration
#        32         f1_additive        no_selection        no_migration
#        33         f1_additive        no_selection        no_migration
#        34         f1_additive        no_selection        no_migration
#        35         f1_additive        no_selection        no_migration
#        36         f1_additive        no_selection        no_migration
#        37         f1_additive        no_selection        no_migration
#        38         f1_additive        no_selection        no_migration
#        39         f1_additive        no_selection        no_migration
#        40         f1_additive        no_selection        no_migration
#
# Generating initial plate
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm multiple_pair_top finished
#
# Algorithm: simple_screening
#
#
#  transfer community_phenotype selection_algorithm migration_algorithm
#         1      f2_interaction        no_selection        no_migration
#         2      f2_interaction        no_selection        no_migration
#         3      f2_interaction        no_selection        no_migration
#         4      f2_interaction        no_selection        no_migration
#         5      f2_interaction        no_selection        no_migration
#         6      f2_interaction        no_selection        no_migration
#         7      f2_interaction        no_selection        no_migration
#         8      f2_interaction        no_selection        no_migration
#         9      f2_interaction        no_selection        no_migration
#        10      f2_interaction        no_selection        no_migration
#        11      f2_interaction        no_selection        no_migration
#        12      f2_interaction        no_selection        no_migration
#        13      f2_interaction        no_selection        no_migration
#        14      f2_interaction        no_selection        no_migration
#        15      f2_interaction        no_selection        no_migration
#        16      f2_interaction        no_selection        no_migration
#        17      f2_interaction        no_selection        no_migration
#        18      f2_interaction        no_selection        no_migration
#        19      f2_interaction        no_selection        no_migration
#        20      f2_interaction        no_selection        no_migration
#        21      f2_interaction        no_selection        no_migration
#        22      f2_interaction        no_selection        no_migration
#        23      f2_interaction        no_selection        no_migration
#        24      f2_interaction        no_selection        no_migration
#        25      f2_interaction        no_selection        no_migration
#        26      f2_interaction        no_selection        no_migration
#        27      f2_interaction        no_selection        no_migration
#        28      f2_interaction        no_selection        no_migration
#        29      f2_interaction        no_selection        no_migration
#        30      f2_interaction        no_selection        no_migration
#        31      f2_interaction        no_selection        no_migration
#        32      f2_interaction        no_selection        no_migration
#        33      f2_interaction        no_selection        no_migration
#        34      f2_interaction        no_selection        no_migration
#        35      f2_interaction        no_selection        no_migration
#        36      f2_interaction        no_selection        no_migration
#        37      f2_interaction        no_selection        no_migration
#        38      f2_interaction        no_selection        no_migration
#        39      f2_interaction        no_selection        no_migration
#        40      f2_interaction        no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm simple_screening finished
#
# Algorithm: swenson2000
#
#
#  transfer community_phenotype  selection_algorithm migration_algorithm
#         1      f2_interaction  select_top25percent        no_migration
#         2      f2_interaction  select_top25percent        no_migration
#         3      f2_interaction  select_top25percent        no_migration
#         4      f2_interaction  select_top25percent        no_migration
#         5      f2_interaction  select_top25percent        no_migration
#         6      f2_interaction  select_top25percent        no_migration
#         7      f2_interaction  select_top25percent        no_migration
#         8      f2_interaction  select_top25percent        no_migration
#         9      f2_interaction  select_top25percent        no_migration
#        10      f2_interaction  select_top25percent        no_migration
#        11      f2_interaction  select_top25percent        no_migration
#        12      f2_interaction  select_top25percent        no_migration
#        13      f2_interaction  select_top25percent        no_migration
#        14      f2_interaction  select_top25percent        no_migration
#        15      f2_interaction  select_top25percent        no_migration
#        16      f2_interaction  select_top25percent        no_migration
#        17      f2_interaction  select_top25percent        no_migration
#        18      f2_interaction  select_top25percent        no_migration
#        19      f2_interaction  select_top25percent        no_migration
#        20      f2_interaction  select_top25percent        no_migration
#        21      f2_interaction         no_selection        no_migration
#        22      f2_interaction         no_selection        no_migration
#        23      f2_interaction         no_selection        no_migration
#        24      f2_interaction         no_selection        no_migration
#        25      f2_interaction         no_selection        no_migration
#        26      f2_interaction         no_selection        no_migration
#        27      f2_interaction         no_selection        no_migration
#        28      f2_interaction         no_selection        no_migration
#        29      f2_interaction         no_selection        no_migration
#        30      f2_interaction         no_selection        no_migration
#        31      f2_interaction         no_selection        no_migration
#        32      f2_interaction         no_selection        no_migration
#        33      f2_interaction         no_selection        no_migration
#        34      f2_interaction         no_selection        no_migration
#        35      f2_interaction         no_selection        no_migration
#        36      f2_interaction         no_selection        no_migration
#        37      f2_interaction         no_selection        no_migration
#        38      f2_interaction         no_selection        no_migration
#        39      f2_interaction         no_selection        no_migration
#        40      f2_interaction         no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm swenson2000 finished
#
# Algorithm: direct_selection
#
#
#  transfer community_phenotype      selection_algorithm       migration_algorithm
#         1      f2_interaction             no_selection              no_migration
#         2      f2_interaction             no_selection              no_migration
#         3      f2_interaction             no_selection              no_migration
#         4      f2_interaction             no_selection              no_migration
#         5      f2_interaction             no_selection              no_migration
#         6      f2_interaction             no_selection              no_migration
#         7      f2_interaction             no_selection              no_migration
#         8      f2_interaction             no_selection              no_migration
#         9      f2_interaction             no_selection              no_migration
#        10      f2_interaction             no_selection              no_migration
#        11      f2_interaction             no_selection              no_migration
#        12      f2_interaction             no_selection              no_migration
#        13      f2_interaction             no_selection              no_migration
#        14      f2_interaction             no_selection              no_migration
#        15      f2_interaction             no_selection              no_migration
#        16      f2_interaction             no_selection              no_migration
#        17      f2_interaction             no_selection              no_migration
#        18      f2_interaction             no_selection              no_migration
#        19      f2_interaction             no_selection              no_migration
#        20      f2_interaction  direct_selection_select  direct_selection_migrate
#        21      f2_interaction             no_selection              no_migration
#        22      f2_interaction             no_selection              no_migration
#        23      f2_interaction             no_selection              no_migration
#        24      f2_interaction             no_selection              no_migration
#        25      f2_interaction             no_selection              no_migration
#        26      f2_interaction             no_selection              no_migration
#        27      f2_interaction             no_selection              no_migration
#        28      f2_interaction             no_selection              no_migration
#        29      f2_interaction             no_selection              no_migration
#        30      f2_interaction             no_selection              no_migration
#        31      f2_interaction             no_selection              no_migration
#        32      f2_interaction             no_selection              no_migration
#        33      f2_interaction             no_selection              no_migration
#        34      f2_interaction             no_selection              no_migration
#        35      f2_interaction             no_selection              no_migration
#        36      f2_interaction             no_selection              no_migration
#        37      f2_interaction             no_selection              no_migration
#        38      f2_interaction             no_selection              no_migration
#        39      f2_interaction             no_selection              no_migration
#        40      f2_interaction             no_selection              no_migration
#
# Generating initial plate
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm direct_selection finished
#
# Algorithm: panke_buisse2015
#
#
#  transfer community_phenotype selection_algorithm migration_algorithm
#         1      f2_interaction   pool_top25percent        no_migration
#         2      f2_interaction   pool_top25percent        no_migration
#         3      f2_interaction   pool_top25percent        no_migration
#         4      f2_interaction   pool_top25percent        no_migration
#         5      f2_interaction   pool_top25percent        no_migration
#         6      f2_interaction   pool_top25percent        no_migration
#         7      f2_interaction   pool_top25percent        no_migration
#         8      f2_interaction   pool_top25percent        no_migration
#         9      f2_interaction   pool_top25percent        no_migration
#        10      f2_interaction   pool_top25percent        no_migration
#        11      f2_interaction   pool_top25percent        no_migration
#        12      f2_interaction   pool_top25percent        no_migration
#        13      f2_interaction   pool_top25percent        no_migration
#        14      f2_interaction   pool_top25percent        no_migration
#        15      f2_interaction   pool_top25percent        no_migration
#        16      f2_interaction   pool_top25percent        no_migration
#        17      f2_interaction   pool_top25percent        no_migration
#        18      f2_interaction   pool_top25percent        no_migration
#        19      f2_interaction   pool_top25percent        no_migration
#        20      f2_interaction   pool_top25percent        no_migration
#        21      f2_interaction        no_selection        no_migration
#        22      f2_interaction        no_selection        no_migration
#        23      f2_interaction        no_selection        no_migration
#        24      f2_interaction        no_selection        no_migration
#        25      f2_interaction        no_selection        no_migration
#        26      f2_interaction        no_selection        no_migration
#        27      f2_interaction        no_selection        no_migration
#        28      f2_interaction        no_selection        no_migration
#        29      f2_interaction        no_selection        no_migration
#        30      f2_interaction        no_selection        no_migration
#        31      f2_interaction        no_selection        no_migration
#        32      f2_interaction        no_selection        no_migration
#        33      f2_interaction        no_selection        no_migration
#        34      f2_interaction        no_selection        no_migration
#        35      f2_interaction        no_selection        no_migration
#        36      f2_interaction        no_selection        no_migration
#        37      f2_interaction        no_selection        no_migration
#        38      f2_interaction        no_selection        no_migration
#        39      f2_interaction        no_selection        no_migration
#        40      f2_interaction        no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm panke_buisse2015 finished
#
# Algorithm: pair_top_communities
#
#
#  transfer community_phenotype selection_algorithm migration_algorithm
#         1      f2_interaction        no_selection        no_migration
#         2      f2_interaction        no_selection        no_migration
#         3      f2_interaction        no_selection        no_migration
#         4      f2_interaction        no_selection        no_migration
#         5      f2_interaction        no_selection        no_migration
#         6      f2_interaction        no_selection        no_migration
#         7      f2_interaction        no_selection        no_migration
#         8      f2_interaction        no_selection        no_migration
#         9      f2_interaction        no_selection        no_migration
#        10      f2_interaction        no_selection        no_migration
#        11      f2_interaction        no_selection        no_migration
#        12      f2_interaction        no_selection        no_migration
#        13      f2_interaction        no_selection        no_migration
#        14      f2_interaction        no_selection        no_migration
#        15      f2_interaction        no_selection        no_migration
#        16      f2_interaction        no_selection        no_migration
#        17      f2_interaction        no_selection        no_migration
#        18      f2_interaction        no_selection        no_migration
#        19      f2_interaction        no_selection        no_migration
#        20      f2_interaction            pair_top        no_migration
#        21      f2_interaction        no_selection        no_migration
#        22      f2_interaction        no_selection        no_migration
#        23      f2_interaction        no_selection        no_migration
#        24      f2_interaction        no_selection        no_migration
#        25      f2_interaction        no_selection        no_migration
#        26      f2_interaction        no_selection        no_migration
#        27      f2_interaction        no_selection        no_migration
#        28      f2_interaction        no_selection        no_migration
#        29      f2_interaction        no_selection        no_migration
#        30      f2_interaction        no_selection        no_migration
#        31      f2_interaction        no_selection        no_migration
#        32      f2_interaction        no_selection        no_migration
#        33      f2_interaction        no_selection        no_migration
#        34      f2_interaction        no_selection        no_migration
#        35      f2_interaction        no_selection        no_migration
#        36      f2_interaction        no_selection        no_migration
#        37      f2_interaction        no_selection        no_migration
#        38      f2_interaction        no_selection        no_migration
#        39      f2_interaction        no_selection        no_migration
#        40      f2_interaction        no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm pair_top_communities finished
#
# Algorithm: multiple_pair_top
#
#
#  transfer community_phenotype selection_algorithm migration_algorithm
#         1      f2_interaction            pair_top        no_migration
#         2      f2_interaction            pair_top        no_migration
#         3      f2_interaction            pair_top        no_migration
#         4      f2_interaction            pair_top        no_migration
#         5      f2_interaction            pair_top        no_migration
#         6      f2_interaction            pair_top        no_migration
#         7      f2_interaction            pair_top        no_migration
#         8      f2_interaction            pair_top        no_migration
#         9      f2_interaction            pair_top        no_migration
#        10      f2_interaction            pair_top        no_migration
#        11      f2_interaction            pair_top        no_migration
#        12      f2_interaction            pair_top        no_migration
#        13      f2_interaction            pair_top        no_migration
#        14      f2_interaction            pair_top        no_migration
#        15      f2_interaction            pair_top        no_migration
#        16      f2_interaction            pair_top        no_migration
#        17      f2_interaction            pair_top        no_migration
#        18      f2_interaction            pair_top        no_migration
#        19      f2_interaction            pair_top        no_migration
#        20      f2_interaction            pair_top        no_migration
#        21      f2_interaction        no_selection        no_migration
#        22      f2_interaction        no_selection        no_migration
#        23      f2_interaction        no_selection        no_migration
#        24      f2_interaction        no_selection        no_migration
#        25      f2_interaction        no_selection        no_migration
#        26      f2_interaction        no_selection        no_migration
#        27      f2_interaction        no_selection        no_migration
#        28      f2_interaction        no_selection        no_migration
#        29      f2_interaction        no_selection        no_migration
#        30      f2_interaction        no_selection        no_migration
#        31      f2_interaction        no_selection        no_migration
#        32      f2_interaction        no_selection        no_migration
#        33      f2_interaction        no_selection        no_migration
#        34      f2_interaction        no_selection        no_migration
#        35      f2_interaction        no_selection        no_migration
#        36      f2_interaction        no_selection        no_migration
#        37      f2_interaction        no_selection        no_migration
#        38      f2_interaction        no_selection        no_migration
#        39      f2_interaction        no_selection        no_migration
#        40      f2_interaction        no_selection        no_migration
#
# Generating initial plate
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm multiple_pair_top finished
#
# Algorithm: simple_screening
#
#
#  transfer community_phenotype selection_algorithm migration_algorithm
#         1  f3_additive_binary        no_selection        no_migration
#         2  f3_additive_binary        no_selection        no_migration
#         3  f3_additive_binary        no_selection        no_migration
#         4  f3_additive_binary        no_selection        no_migration
#         5  f3_additive_binary        no_selection        no_migration
#         6  f3_additive_binary        no_selection        no_migration
#         7  f3_additive_binary        no_selection        no_migration
#         8  f3_additive_binary        no_selection        no_migration
#         9  f3_additive_binary        no_selection        no_migration
#        10  f3_additive_binary        no_selection        no_migration
#        11  f3_additive_binary        no_selection        no_migration
#        12  f3_additive_binary        no_selection        no_migration
#        13  f3_additive_binary        no_selection        no_migration
#        14  f3_additive_binary        no_selection        no_migration
#        15  f3_additive_binary        no_selection        no_migration
#        16  f3_additive_binary        no_selection        no_migration
#        17  f3_additive_binary        no_selection        no_migration
#        18  f3_additive_binary        no_selection        no_migration
#        19  f3_additive_binary        no_selection        no_migration
#        20  f3_additive_binary        no_selection        no_migration
#        21  f3_additive_binary        no_selection        no_migration
#        22  f3_additive_binary        no_selection        no_migration
#        23  f3_additive_binary        no_selection        no_migration
#        24  f3_additive_binary        no_selection        no_migration
#        25  f3_additive_binary        no_selection        no_migration
#        26  f3_additive_binary        no_selection        no_migration
#        27  f3_additive_binary        no_selection        no_migration
#        28  f3_additive_binary        no_selection        no_migration
#        29  f3_additive_binary        no_selection        no_migration
#        30  f3_additive_binary        no_selection        no_migration
#        31  f3_additive_binary        no_selection        no_migration
#        32  f3_additive_binary        no_selection        no_migration
#        33  f3_additive_binary        no_selection        no_migration
#        34  f3_additive_binary        no_selection        no_migration
#        35  f3_additive_binary        no_selection        no_migration
#        36  f3_additive_binary        no_selection        no_migration
#        37  f3_additive_binary        no_selection        no_migration
#        38  f3_additive_binary        no_selection        no_migration
#        39  f3_additive_binary        no_selection        no_migration
#        40  f3_additive_binary        no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm simple_screening finished
#
# Algorithm: swenson2000
#
#
#  transfer community_phenotype  selection_algorithm migration_algorithm
#         1  f3_additive_binary  select_top25percent        no_migration
#         2  f3_additive_binary  select_top25percent        no_migration
#         3  f3_additive_binary  select_top25percent        no_migration
#         4  f3_additive_binary  select_top25percent        no_migration
#         5  f3_additive_binary  select_top25percent        no_migration
#         6  f3_additive_binary  select_top25percent        no_migration
#         7  f3_additive_binary  select_top25percent        no_migration
#         8  f3_additive_binary  select_top25percent        no_migration
#         9  f3_additive_binary  select_top25percent        no_migration
#        10  f3_additive_binary  select_top25percent        no_migration
#        11  f3_additive_binary  select_top25percent        no_migration
#        12  f3_additive_binary  select_top25percent        no_migration
#        13  f3_additive_binary  select_top25percent        no_migration
#        14  f3_additive_binary  select_top25percent        no_migration
#        15  f3_additive_binary  select_top25percent        no_migration
#        16  f3_additive_binary  select_top25percent        no_migration
#        17  f3_additive_binary  select_top25percent        no_migration
#        18  f3_additive_binary  select_top25percent        no_migration
#        19  f3_additive_binary  select_top25percent        no_migration
#        20  f3_additive_binary  select_top25percent        no_migration
#        21  f3_additive_binary         no_selection        no_migration
#        22  f3_additive_binary         no_selection        no_migration
#        23  f3_additive_binary         no_selection        no_migration
#        24  f3_additive_binary         no_selection        no_migration
#        25  f3_additive_binary         no_selection        no_migration
#        26  f3_additive_binary         no_selection        no_migration
#        27  f3_additive_binary         no_selection        no_migration
#        28  f3_additive_binary         no_selection        no_migration
#        29  f3_additive_binary         no_selection        no_migration
#        30  f3_additive_binary         no_selection        no_migration
#        31  f3_additive_binary         no_selection        no_migration
#        32  f3_additive_binary         no_selection        no_migration
#        33  f3_additive_binary         no_selection        no_migration
#        34  f3_additive_binary         no_selection        no_migration
#        35  f3_additive_binary         no_selection        no_migration
#        36  f3_additive_binary         no_selection        no_migration
#        37  f3_additive_binary         no_selection        no_migration
#        38  f3_additive_binary         no_selection        no_migration
#        39  f3_additive_binary         no_selection        no_migration
#        40  f3_additive_binary         no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm swenson2000 finished
#
# Algorithm: direct_selection
#
#
#  transfer community_phenotype      selection_algorithm       migration_algorithm
#         1  f3_additive_binary             no_selection              no_migration
#         2  f3_additive_binary             no_selection              no_migration
#         3  f3_additive_binary             no_selection              no_migration
#         4  f3_additive_binary             no_selection              no_migration
#         5  f3_additive_binary             no_selection              no_migration
#         6  f3_additive_binary             no_selection              no_migration
#         7  f3_additive_binary             no_selection              no_migration
#         8  f3_additive_binary             no_selection              no_migration
#         9  f3_additive_binary             no_selection              no_migration
#        10  f3_additive_binary             no_selection              no_migration
#        11  f3_additive_binary             no_selection              no_migration
#        12  f3_additive_binary             no_selection              no_migration
#        13  f3_additive_binary             no_selection              no_migration
#        14  f3_additive_binary             no_selection              no_migration
#        15  f3_additive_binary             no_selection              no_migration
#        16  f3_additive_binary             no_selection              no_migration
#        17  f3_additive_binary             no_selection              no_migration
#        18  f3_additive_binary             no_selection              no_migration
#        19  f3_additive_binary             no_selection              no_migration
#        20  f3_additive_binary  direct_selection_select  direct_selection_migrate
#        21  f3_additive_binary             no_selection              no_migration
#        22  f3_additive_binary             no_selection              no_migration
#        23  f3_additive_binary             no_selection              no_migration
#        24  f3_additive_binary             no_selection              no_migration
#        25  f3_additive_binary             no_selection              no_migration
#        26  f3_additive_binary             no_selection              no_migration
#        27  f3_additive_binary             no_selection              no_migration
#        28  f3_additive_binary             no_selection              no_migration
#        29  f3_additive_binary             no_selection              no_migration
#        30  f3_additive_binary             no_selection              no_migration
#        31  f3_additive_binary             no_selection              no_migration
#        32  f3_additive_binary             no_selection              no_migration
# ...
#        28  f6_resident_growth         no_selection        no_migration
#        29  f6_resident_growth         no_selection        no_migration
#        30  f6_resident_growth         no_selection        no_migration
#        31  f6_resident_growth         no_selection        no_migration
#        32  f6_resident_growth         no_selection        no_migration
#        33  f6_resident_growth         no_selection        no_migration
#        34  f6_resident_growth         no_selection        no_migration
#        35  f6_resident_growth         no_selection        no_migration
#        36  f6_resident_growth         no_selection        no_migration
#        37  f6_resident_growth         no_selection        no_migration
#        38  f6_resident_growth         no_selection        no_migration
#        39  f6_resident_growth         no_selection        no_migration
#        40  f6_resident_growth         no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Stabilizing the resident community for function f6_resident_growth. Passage for 20 transfers.
# Passaging resident community. Transfer 1
# Passaging resident community. Transfer 6
# Passaging resident community. Transfer 11
# Passaging resident community. Transfer 16
# Finished passaging the resident community. The resident community has 1 species.
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm swenson2000 finished
#
# Algorithm: direct_selection
#
#
#  transfer community_phenotype      selection_algorithm       migration_algorithm
#         1  f6_resident_growth             no_selection              no_migration
#         2  f6_resident_growth             no_selection              no_migration
#         3  f6_resident_growth             no_selection              no_migration
#         4  f6_resident_growth             no_selection              no_migration
#         5  f6_resident_growth             no_selection              no_migration
#         6  f6_resident_growth             no_selection              no_migration
#         7  f6_resident_growth             no_selection              no_migration
#         8  f6_resident_growth             no_selection              no_migration
#         9  f6_resident_growth             no_selection              no_migration
#        10  f6_resident_growth             no_selection              no_migration
#        11  f6_resident_growth             no_selection              no_migration
#        12  f6_resident_growth             no_selection              no_migration
#        13  f6_resident_growth             no_selection              no_migration
#        14  f6_resident_growth             no_selection              no_migration
#        15  f6_resident_growth             no_selection              no_migration
#        16  f6_resident_growth             no_selection              no_migration
#        17  f6_resident_growth             no_selection              no_migration
#        18  f6_resident_growth             no_selection              no_migration
#        19  f6_resident_growth             no_selection              no_migration
#        20  f6_resident_growth  direct_selection_select  direct_selection_migrate
#        21  f6_resident_growth             no_selection              no_migration
#        22  f6_resident_growth             no_selection              no_migration
#        23  f6_resident_growth             no_selection              no_migration
#        24  f6_resident_growth             no_selection              no_migration
#        25  f6_resident_growth             no_selection              no_migration
#        26  f6_resident_growth             no_selection              no_migration
#        27  f6_resident_growth             no_selection              no_migration
#        28  f6_resident_growth             no_selection              no_migration
#        29  f6_resident_growth             no_selection              no_migration
#        30  f6_resident_growth             no_selection              no_migration
#        31  f6_resident_growth             no_selection              no_migration
#        32  f6_resident_growth             no_selection              no_migration
#        33  f6_resident_growth             no_selection              no_migration
#        34  f6_resident_growth             no_selection              no_migration
#        35  f6_resident_growth             no_selection              no_migration
#        36  f6_resident_growth             no_selection              no_migration
#        37  f6_resident_growth             no_selection              no_migration
#        38  f6_resident_growth             no_selection              no_migration
#        39  f6_resident_growth             no_selection              no_migration
#        40  f6_resident_growth             no_selection              no_migration
#
# Generating initial plate
# Adding attributes that are essential to the community function to the plate object
#
# Stabilizing the resident community for function f6_resident_growth. Passage for 20 transfers.
# Passaging resident community. Transfer 1
# Passaging resident community. Transfer 6
# Passaging resident community. Transfer 11
# Passaging resident community. Transfer 16
# Finished passaging the resident community. The resident community has 1 species.
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm direct_selection finished
#
# Algorithm: panke_buisse2015
#
#
#  transfer community_phenotype selection_algorithm migration_algorithm
#         1  f6_resident_growth   pool_top25percent        no_migration
#         2  f6_resident_growth   pool_top25percent        no_migration
#         3  f6_resident_growth   pool_top25percent        no_migration
#         4  f6_resident_growth   pool_top25percent        no_migration
#         5  f6_resident_growth   pool_top25percent        no_migration
#         6  f6_resident_growth   pool_top25percent        no_migration
#         7  f6_resident_growth   pool_top25percent        no_migration
#         8  f6_resident_growth   pool_top25percent        no_migration
#         9  f6_resident_growth   pool_top25percent        no_migration
#        10  f6_resident_growth   pool_top25percent        no_migration
#        11  f6_resident_growth   pool_top25percent        no_migration
#        12  f6_resident_growth   pool_top25percent        no_migration
#        13  f6_resident_growth   pool_top25percent        no_migration
#        14  f6_resident_growth   pool_top25percent        no_migration
#        15  f6_resident_growth   pool_top25percent        no_migration
#        16  f6_resident_growth   pool_top25percent        no_migration
#        17  f6_resident_growth   pool_top25percent        no_migration
#        18  f6_resident_growth   pool_top25percent        no_migration
#        19  f6_resident_growth   pool_top25percent        no_migration
#        20  f6_resident_growth   pool_top25percent        no_migration
#        21  f6_resident_growth        no_selection        no_migration
#        22  f6_resident_growth        no_selection        no_migration
#        23  f6_resident_growth        no_selection        no_migration
#        24  f6_resident_growth        no_selection        no_migration
#        25  f6_resident_growth        no_selection        no_migration
#        26  f6_resident_growth        no_selection        no_migration
#        27  f6_resident_growth        no_selection        no_migration
#        28  f6_resident_growth        no_selection        no_migration
#        29  f6_resident_growth        no_selection        no_migration
#        30  f6_resident_growth        no_selection        no_migration
#        31  f6_resident_growth        no_selection        no_migration
#        32  f6_resident_growth        no_selection        no_migration
#        33  f6_resident_growth        no_selection        no_migration
#        34  f6_resident_growth        no_selection        no_migration
#        35  f6_resident_growth        no_selection        no_migration
#        36  f6_resident_growth        no_selection        no_migration
#        37  f6_resident_growth        no_selection        no_migration
#        38  f6_resident_growth        no_selection        no_migration
#        39  f6_resident_growth        no_selection        no_migration
#        40  f6_resident_growth        no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Stabilizing the resident community for function f6_resident_growth. Passage for 20 transfers.
# Passaging resident community. Transfer 1
# Passaging resident community. Transfer 6
# Passaging resident community. Transfer 11
# Passaging resident community. Transfer 16
# Finished passaging the resident community. The resident community has 1 species.
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm panke_buisse2015 finished
#
# Algorithm: pair_top_communities
#
#
#  transfer community_phenotype selection_algorithm migration_algorithm
#         1  f6_resident_growth        no_selection        no_migration
#         2  f6_resident_growth        no_selection        no_migration
#         3  f6_resident_growth        no_selection        no_migration
#         4  f6_resident_growth        no_selection        no_migration
#         5  f6_resident_growth        no_selection        no_migration
#         6  f6_resident_growth        no_selection        no_migration
#         7  f6_resident_growth        no_selection        no_migration
#         8  f6_resident_growth        no_selection        no_migration
#         9  f6_resident_growth        no_selection        no_migration
#        10  f6_resident_growth        no_selection        no_migration
#        11  f6_resident_growth        no_selection        no_migration
#        12  f6_resident_growth        no_selection        no_migration
#        13  f6_resident_growth        no_selection        no_migration
#        14  f6_resident_growth        no_selection        no_migration
#        15  f6_resident_growth        no_selection        no_migration
#        16  f6_resident_growth        no_selection        no_migration
#        17  f6_resident_growth        no_selection        no_migration
#        18  f6_resident_growth        no_selection        no_migration
#        19  f6_resident_growth        no_selection        no_migration
#        20  f6_resident_growth            pair_top        no_migration
#        21  f6_resident_growth        no_selection        no_migration
#        22  f6_resident_growth        no_selection        no_migration
#        23  f6_resident_growth        no_selection        no_migration
#        24  f6_resident_growth        no_selection        no_migration
#        25  f6_resident_growth        no_selection        no_migration
#        26  f6_resident_growth        no_selection        no_migration
#        27  f6_resident_growth        no_selection        no_migration
#        28  f6_resident_growth        no_selection        no_migration
#        29  f6_resident_growth        no_selection        no_migration
#        30  f6_resident_growth        no_selection        no_migration
#        31  f6_resident_growth        no_selection        no_migration
#        32  f6_resident_growth        no_selection        no_migration
#        33  f6_resident_growth        no_selection        no_migration
#        34  f6_resident_growth        no_selection        no_migration
#        35  f6_resident_growth        no_selection        no_migration
#        36  f6_resident_growth        no_selection        no_migration
#        37  f6_resident_growth        no_selection        no_migration
#        38  f6_resident_growth        no_selection        no_migration
#        39  f6_resident_growth        no_selection        no_migration
#        40  f6_resident_growth        no_selection        no_migration
#
# Generating initial plate
#
# Adding attributes that are essential to the community function to the plate object
#
# Stabilizing the resident community for function f6_resident_growth. Passage for 20 transfers.
# Passaging resident community. Transfer 1
# Passaging resident community. Transfer 6
# Passaging resident community. Transfer 11
# Passaging resident community. Transfer 16
# Finished passaging the resident community. The resident community has 1 species.
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm pair_top_communities finished
#
# Algorithm: multiple_pair_top
#
#
#  transfer community_phenotype selection_algorithm migration_algorithm
#         1  f6_resident_growth            pair_top        no_migration
#         2  f6_resident_growth            pair_top        no_migration
#         3  f6_resident_growth            pair_top        no_migration
#         4  f6_resident_growth            pair_top        no_migration
#         5  f6_resident_growth            pair_top        no_migration
#         6  f6_resident_growth            pair_top        no_migration
#         7  f6_resident_growth            pair_top        no_migration
#         8  f6_resident_growth            pair_top        no_migration
#         9  f6_resident_growth            pair_top        no_migration
#        10  f6_resident_growth            pair_top        no_migration
#        11  f6_resident_growth            pair_top        no_migration
#        12  f6_resident_growth            pair_top        no_migration
#        13  f6_resident_growth            pair_top        no_migration
#        14  f6_resident_growth            pair_top        no_migration
#        15  f6_resident_growth            pair_top        no_migration
#        16  f6_resident_growth            pair_top        no_migration
#        17  f6_resident_growth            pair_top        no_migration
#        18  f6_resident_growth            pair_top        no_migration
#        19  f6_resident_growth            pair_top        no_migration
#        20  f6_resident_growth            pair_top        no_migration
#        21  f6_resident_growth        no_selection        no_migration
#        22  f6_resident_growth        no_selection        no_migration
#        23  f6_resident_growth        no_selection        no_migration
#        24  f6_resident_growth        no_selection        no_migration
#        25  f6_resident_growth        no_selection        no_migration
#        26  f6_resident_growth        no_selection        no_migration
#        27  f6_resident_growth        no_selection        no_migration
#        28  f6_resident_growth        no_selection        no_migration
#        29  f6_resident_growth        no_selection        no_migration
#        30  f6_resident_growth        no_selection        no_migration
#        31  f6_resident_growth        no_selection        no_migration
#        32  f6_resident_growth        no_selection        no_migration
#        33  f6_resident_growth        no_selection        no_migration
#        34  f6_resident_growth        no_selection        no_migration
#        35  f6_resident_growth        no_selection        no_migration
#        36  f6_resident_growth        no_selection        no_migration
#        37  f6_resident_growth        no_selection        no_migration
#        38  f6_resident_growth        no_selection        no_migration
#        39  f6_resident_growth        no_selection        no_migration
#        40  f6_resident_growth        no_selection        no_migration
#
# Generating initial plate
# Adding attributes that are essential to the community function to the plate object
#
# Stabilizing the resident community for function f6_resident_growth. Passage for 20 transfers.
# Passaging resident community. Transfer 1
# Passaging resident community. Transfer 6
# Passaging resident community. Transfer 11
# Passaging resident community. Transfer 16
# Finished passaging the resident community. The resident community has 1 species.
#
# Start propogation
# Transfer 1
# Transfer 6
# Transfer 11
# Transfer 16
# Transfer 21
# Transfer 26
# Transfer 31
# Transfer 36
#
# Algorithm multiple_pair_top finished
